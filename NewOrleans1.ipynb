# %%
import pandas as pd
import numpy as np
import seaborn as sns
import statsmodels.api as sm
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('~/downloads/listings.csv', delimiter = ',', header = 0)
df
# Out:
#             id                                             name    host_id  \
# 0        10291                    Spacious Cottage in Mid-City!      31004
# 1        19091                   Fully Furnished Cozy Apartment      72880
# 2        26834                 Maison Mandeville in the Marigny     114452
# 3        66972              The Retreat in Lovely Bayou St John     329415
# 4        71624               Ravenwood Manor (Historic Bywater)     367223
# ...        ...                                              ...        ...
# 6913  43697672                  NOLA | Downtown 1Bedroom  Condo  344053507
# 6914  43697809                   NOLA | Downtown 1Bedroom Condo  344053507
# 6915  43701886  Haunted French Quarter Mansion- Mardi Gras Room  112910785
# 6916  43701924    Haunted French Quarter Mansion- Queen Bedroom  112910785
# 6917  43716135  Designer Bachelorette pad near French Quarter!.   16753214
#
# ...
