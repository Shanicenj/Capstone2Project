# %%
import pandas as pd
import numpy as np
import seaborn as sns
import statsmodels.api as sm
import matplotlib.pyplot as plt
from matplotlib import pyplot as plt

# %%
df = pd.read_csv('~/downloads/listings-2.csv', delimiter = ',', header = 0)
#df.drop(['listing_url', 'scrape_id', 'host_response_rate', 'host_neighbourhood', 'host_listings_count', 'review_scores_communication', 'review_scores_checkin', 'host_verifications', 'last_scraped', 'name', 'summary', 'space', 'description', 'experiences_offered', 'neighborhood_overview', 'notes', 'access', 'interaction', 'house_rules', 'thumbnail_url', 'medium_url', 'picture_url', 'xl_picture_url', 'host_url', 'host_about', 'host_response_time', 'host_acceptance_rate', 'host_thumbnail_url', 'host_picture_url', 'host_has_profile_pic', 'street', 'neighbourhood', 'city', 'state', 'zipcode', 'market', 'smart_location', 'country_code', 'country', 'is_location_exact', 'bed_type', 'security_deposit', 'calendar_last_scraped', 'first_review', 'last_review', 'review_scores_rating', 'review_scores_cleanliness', 'review_scores_location', 'review_scores_value', 'license', 'jurisdiction_names', 'cancellation_policy', 'require_guest_profile_picture', 'review_scores_accuracy', 'calculated_host_listings_count_private_rooms', 'calculated_host_listings_count_entire_homes', 'require_guest_phone_verification'], axis=1, inplace = True)

# %%
pd.options.display.max_rows = 50
pd.set_option('display.max_columns', None)
pd.set_option('display.width', 1000)

# %%
df
# Out:
#             id                            listing_url       scrape_id last_scraped                                             name                                            summary                                              space                                        description experiences_offered                              neighborhood_overview notes                                            transit                                             access                                        interaction                                        house_rules  thumbnail_url  medium_url                                        picture_url  xl_picture_url    host_id                                     host_url host_name  host_since                          host_location                                         host_about host_response_time host_response_rate host_acceptance_rate host_is_superhost                                 host_thumbnail_url  \
# ...

# %%
#df['host_location'].unique().tolist()

# %%
#hostlocation_count = df.host_location.value_counts()
#hostlocation_count

# %%
#df['host_is_superhost'].unique().tolist()

# %%
# super_hostcount = df.host_is_superhost.value_counts()
# super_hostcount

# %%
# #pd.options.display.max_rows = 999
# neighborhood_propertycount = df.neighbourhood_cleansed.value_counts()
# neighborhood_propertycount

# %%
#neighborhood_propertycount.head(10)
#neighborhood_propertycount.head(5)

# %%
# neighborhood_propertycount.tail(10)
#neighborhood_propertycount.tail(5)

# %%
# ax = sns.scatterplot(x = "number_of_reviews", y = "Percentage of International Students", data = df, color = 'green', marker = 'p')
# ax = sns.lmplot(x = "Vulnerability Score", y = "Percentage of International Students", data = df, height = 8, aspect = 1)

# %%
df['host_response_time'].unique().tolist()
# Out:
# ['within an hour',
#  nan,
#  'within a day',
#  'within a few hours',
#  'a few days or more']

# %%
df.info(verbose=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6918 entries, 0 to 6917
# Data columns (total 106 columns):
#  #   Column                                        Dtype
# ---  ------                                        -----
#  0   id                                            int64
#  1   listing_url                                   object
#  2   scrape_id                                     int64
#  3   last_scraped                                  object
#  4   name                                          object
#  5   summary                                       object
#  6   space                                         object
#  7   description                                   object
#  8   experiences_offered                           object
#  9   neighborhood_overview                         object
#  10  notes                                         object
#  11  transit                                       object
# ...

# %%
df.price
# Out:
# 0       $300.00
# 1       $100.00
# 2        $90.00
# 3       $123.00
# 4       $130.00
#          ...
# 6913     $99.00
# 6914     $99.00
# 6915     $72.00
# 6916     $72.00
# 6917    $499.00
# Name: price, Length: 6918, dtype: object

# %%
df.host_response_rate
# Out:
# 0       100%
# 1        NaN
# 2       100%
# 3        67%
# 4       100%
#         ...
# 6913    100%
# 6914    100%
# 6915    100%
# 6916    100%
# 6917    100%
# Name: host_response_rate, Length: 6918, dtype: object

# %%
df['price'] = df['price'].map(lambda x: x.lstrip('$').rstrip('aAbBcC'))

# %%
df.price
# Out:
# 0       300.00
# 1       100.00
# 2        90.00
# 3       123.00
# 4       130.00
#          ...
# 6913     99.00
# 6914     99.00
# 6915     72.00
# 6916     72.00
# 6917    499.00
# Name: price, Length: 6918, dtype: object

# %%
df['price']= df['price'].str.replace(',', '')

# %%
df['price'] = df['price'].astype('float64')

# %%
df.price
# Out:
# 0       300.0
# 1       100.0
# 2        90.0
# 3       123.0
# 4       130.0
#         ...
# 6913     99.0
# 6914     99.0
# 6915     72.0
# 6916     72.0
# 6917    499.0
# Name: price, Length: 6918, dtype: float64

# %%
df['host_response_rate']= df['host_response_rate'].str.replace('%', '')

# %%
df['host_response_rate'] = df['host_response_rate'].astype('float64')

# %%
df.host_response_rate
# Out:
# 0       100.0
# 1         NaN
# 2       100.0
# 3        67.0
# 4       100.0
#         ...
# 6913    100.0
# 6914    100.0
# 6915    100.0
# 6916    100.0
# 6917    100.0
# Name: host_response_rate, Length: 6918, dtype: float64

# %%
# sns.set_context("poster", font_scale = 1.0, rc={"grid.linewidth": 1.0})
# sns.pairplot(df[['price', 'host_response_rate', 'number_of_reviews']], plot_kws = {"color": "green"}, height = 5)
ax = sns.scatterplot(x = "number_of_reviews", y = "price", data = df, color = 'green', marker = 'p')
ax = sns.lmplot(x = "number_of_reviews", y = "price", data = df, height = 8, aspect = 1)

# %%
ax = sns.scatterplot(x = "number_of_reviews", y = "host_response_rate", data = df, color = 'green', marker = 'p')
ax = sns.lmplot(x = "number_of_reviews", y = "host_response_rate", data = df, height = 8, aspect = 1)
